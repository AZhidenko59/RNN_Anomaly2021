# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
# %matplotlib inline
#%matplotlib qt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import Dropout

import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd

import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot
import cufflinks

from random import random
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
t = np.linspace(0,1,1024)
f1, f2, f3, f4 = 10, 40, 100, 150
Fort=2.0*np.sin(2*np.pi*f1*t)+1.5*np.sin(2*np.pi*f2*t)+0.8*np.sin(2*np.pi*f3*t)+0.5*np.sin(2*np.pi*f4*t)+0.2*np.random.randn(len(t))+0.01*t
plt.figure(figsize = (10, 5))
plt.plot(t, Fort, 'k')
plt.show()

# %%
n_point=20 #Количество предыдущих точек, по которым предсказывается следующее значение
fn_tr=768 #Конец обучающей выборки
st_test=fn_tr-n_point #Начало тестовой выборки
fn_test=1024 #Конец тестовой выборки
len_f=1024 #Длина исходного ВР

Ft=Fort
Ft[900:950]=Ft[900:950]+np.sin(2*np.pi*200*t[900:950]) #Вносим искусственную аномалию во ВР
scaler = MinMaxScaler(feature_range=(0, 1))
F=np.array(Ft[:len_f])
F = F.reshape(-1, 1)
F = scaler.fit_transform(F)
F_tr = F[:fn_tr]
F_test = F[st_test:]
plt.figure(figsize = (10, 5))
plt.plot(F, 'k')
plt.plot(np.r_[:fn_tr],F_tr, 'b', label='Train')
plt.plot(np.r_[st_test:fn_test],F_test, 'r', label='Test')
plt.title('График ВР')
plt.legend()
plt.show()

# %%
#Предобработка исходных данных в формат, понимаемый слоем LSTM-сети, в виде «порций» (batches) для обучения/валидации
from keras.preprocessing.sequence import TimeseriesGenerator
data_gen_tr = TimeseriesGenerator(F_tr, F_tr, length=n_point, sampling_rate=1, batch_size=fn_tr)
batch_0_tr = data_gen_tr[0]
x_tr, y_tr = batch_0_tr # вход и обучающий выход для сети
print(x_tr.shape) # точки обучения
xx_tr=np.reshape(x_tr, (x_tr.shape[0], 1, x_tr.shape[1]))
yy_tr=y_tr
print(xx_tr.shape) # меняем местами размерности
print(yy_tr.shape)
# Out:
# (748, 20, 1)
# (748, 1, 20)
# (748, 1)

# %%
#Для тестовой проверки прогноза исходные точки аналогично представим в виде «порций»
data_gen_test = TimeseriesGenerator(F_test, F_test, length=n_point, sampling_rate=1, batch_size=fn_tr)
batch_0_test = data_gen_test[0]
x_test, y_test = batch_0_test
xx_test=np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1]))
yy_test = y_test
print(xx_test.shape) #
print(yy_test.shape) #
# Out:
# (256, 1, 20)
# (256, 1)

# %%
#Модель из 3 слоев LSTM
from tensorflow.keras.utils import plot_model
model = Sequential()
model.add(LSTM(units=40, return_sequences=True, input_shape=(1, n_point)))
model.add(Dropout(0.3))
model.add(LSTM(units=40, return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=40))
model.add(Dense(units = 1))
model.compile(optimizer = 'Adam', loss = 'mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 1, 40)             9760
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 40)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1, 40)             12960
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 40)             0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 40)                12960
# _________________________________________________________________
# dense (Dense)                (None, 1)                 41
# =================================================================
# Total params: 35,721
# Trainable params: 35,721
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Производим обучение нашей модели
history = model.fit(xx_tr, yy_tr, validation_data=(xx_test, yy_test), epochs = 100, verbose=1)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 31s 254ms/step - loss: 0.2423 - val_loss: 0.1193
# Epoch 2/100
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0702 - val_loss: 0.0389
# Epoch 3/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0448 - val_loss: 0.0374
# Epoch 4/100
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0382 - val_loss: 0.0305
# Epoch 5/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.0295 - val_loss: 0.0245
# Epoch 6/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0247 - val_loss: 0.0181
# Epoch 7/100
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0191 - val_loss: 0.0138
# Epoch 8/100
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0174 - val_loss: 0.0125
# Epoch 9/100
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0157 - val_loss: 0.0113
# Epoch 10/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0133 - val_loss: 0.0109
# Epoch 11/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0136 - val_loss: 0.0096
# Epoch 12/100
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0122 - val_loss: 0.0089
# Epoch 13/100
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0112 - val_loss: 0.0089
# Epoch 14/100
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0103 - val_loss: 0.0082
# Epoch 15/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0101 - val_loss: 0.0079
# Epoch 16/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0098 - val_loss: 0.0078
# Epoch 17/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0094 - val_loss: 0.0073
# Epoch 18/100
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0081 - val_loss: 0.0072
# Epoch 19/100
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0093 - val_loss: 0.0072
# Epoch 20/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0081 - val_loss: 0.0072
# Epoch 21/100
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0086 - val_loss: 0.0073
# Epoch 22/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0070 - val_loss: 0.0071
# Epoch 23/100
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0080 - val_loss: 0.0070
# Epoch 24/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0076 - val_loss: 0.0069
# Epoch 25/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0079 - val_loss: 0.0070
# Epoch 26/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0074 - val_loss: 0.0070
# Epoch 27/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.0068
# Epoch 28/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0069 - val_loss: 0.0070
# Epoch 29/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0070 - val_loss: 0.0068
# Epoch 30/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0063 - val_loss: 0.0071
# Epoch 31/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0067
# Epoch 32/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0063 - val_loss: 0.0067
# Epoch 33/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0055 - val_loss: 0.0067
# Epoch 34/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0059 - val_loss: 0.0068
# Epoch 35/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0065 - val_loss: 0.0066
# Epoch 36/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0058 - val_loss: 0.0067
# Epoch 37/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0056 - val_loss: 0.0069
# Epoch 38/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0068
# Epoch 39/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0055 - val_loss: 0.0070
# Epoch 40/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0053 - val_loss: 0.0067
# Epoch 41/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0058 - val_loss: 0.0068
# Epoch 42/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0050 - val_loss: 0.0067
# Epoch 43/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0052 - val_loss: 0.0067
# Epoch 44/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0069
# Epoch 45/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 0.0069
# Epoch 46/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 0.0068
# Epoch 47/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0046 - val_loss: 0.0068
# Epoch 48/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0053 - val_loss: 0.0074
# Epoch 49/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0076
# Epoch 50/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0069
# Epoch 51/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 0.0071
# Epoch 52/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0047 - val_loss: 0.0070
# Epoch 53/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0073
# Epoch 54/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0072
# Epoch 55/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0074
# Epoch 56/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0076
# Epoch 57/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0043 - val_loss: 0.0074
# Epoch 58/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 0.0077
# Epoch 59/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0040 - val_loss: 0.0077
# Epoch 60/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0042 - val_loss: 0.0077
# Epoch 61/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0078
# Epoch 62/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0042 - val_loss: 0.0077
# Epoch 63/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0080
# Epoch 64/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0079
# Epoch 65/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0039 - val_loss: 0.0079
# Epoch 66/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 0.0082
# Epoch 67/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0081
# Epoch 68/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0035 - val_loss: 0.0083
# Epoch 69/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 0.0092
# Epoch 70/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0035 - val_loss: 0.0084
# Epoch 71/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0037 - val_loss: 0.0085
# Epoch 72/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0087
# Epoch 73/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0089
# Epoch 74/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0036 - val_loss: 0.0087
# Epoch 75/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0091
# Epoch 76/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0091
# Epoch 77/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0090
# Epoch 78/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0093
# Epoch 79/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0089
# Epoch 80/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0034 - val_loss: 0.0092
# Epoch 81/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0092
# Epoch 82/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0094
# Epoch 83/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 0.0092
# Epoch 84/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0094
# Epoch 85/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0095
# Epoch 86/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0033 - val_loss: 0.0092
# Epoch 87/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 0.0100
# Epoch 88/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 0.0098
# Epoch 89/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0097
# Epoch 90/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0098
# Epoch 91/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 0.0104
# Epoch 92/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0097
# Epoch 93/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0097
# Epoch 94/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0099
# Epoch 95/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 0.0098
# Epoch 96/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0098
# Epoch 97/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 0.0097
# Epoch 98/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 0.0099
# Epoch 99/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 0.0099
# Epoch 100/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0098

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  epochs = range(len(loss))
  plt.figure(figsize = (10, 5))
  plt.plot(epochs, loss, 'b', label='Потери при обучении')
  plt.plot(epochs, val_loss, 'r', label='Потери при проверке')
  plt.title(title)
  plt.legend()
  plt.show()

# %%
#%matplotlib qt
plot_train_history(history,
                   'График зависимости потерь при обучении и проверке модели от количества эпох')

# %%
#Построим ретроспективный прогноз
trainPredict = model.predict(xx_tr)
trainPredict = scaler.inverse_transform(trainPredict)
plt.figure(figsize = (10, 5))
plt.plot(Ft[:len_f], 'k')
plt.plot(np.r_[n_point:fn_tr],trainPredict, 'b')
plt.show()

# %%
#Ошибка
FF1=np.array(Ft[n_point:fn_tr]).reshape(-1,1)
er1=abs(FF1-trainPredict)
plt.figure(figsize = (10, 5))
plt.plot(er1, 'r')
plt.show()

# %%
print(len(trainPredict))
# Out:
# 748

# %%
#Строим получившийся тестовый прогноз в нужном масштабе
#%matplotlib qt
testPredict = model.predict(xx_test)
testPredict = scaler.inverse_transform(testPredict)
plt.figure(figsize = (10, 5))
plt.plot(Ft[:len_f], 'k')
plt.plot(np.r_[fn_tr:len_f],testPredict, 'b')
plt.show()
#cufflinks.go_offline()
#cufflinks.set_config_file(world_readable=True, theme='pearl', offline=True)

# %%
print(len(Ft[fn_tr:len_f]))
# Out:
# 256

# %%
#Ошибка
FF=np.array(Ft[fn_tr:len_f]).reshape(-1,1)
er=abs(FF-testPredict)
plt.figure(figsize = (10, 5))
plt.plot(np.r_[fn_tr:len_f],er, 'r')
plt.title('Ошибка прогноза LSTM')
plt.show()

# %%
print('Матожидание ошибки обучения = ', round(np.mean(er1),5))
print('СКВО ошибки обучения = ', round(np.std(er1),5))
print('Матожидание ошибки прогноза = ', round(np.mean(er),5))
print('СКВО ошибки прогноза = ', round(np.std(er),5))
# Out:
# Матожидание ошибки обучения =  0.2728
# СКВО ошибки обучения =  0.20478
# Матожидание ошибки прогноза =  0.52089
# СКВО ошибки прогноза =  0.61519

# %%
#Скользящее сглаживание по k точкам
def moving_average(series, Date, k):
    f2=[]
    Dt=[]
    N1=int(len(series))
    k1=int((k-1)/2)
    i=k1+1
    while i<= N1-k1:
        tmp=series[i-k1:i+k1]   
        f2.append(np.mean(tmp))
        Dt.append(Date[i])
        i=i+1
    return Dt, f2

# %%
#Скользящее сглаживание ошибки прогноза
[t1,s1] = moving_average(er,np.r_[fn_tr:len_f],15)
plt.figure(figsize = (10, 5))
plt.plot(t1, s1, 'r')
plt.title('Ошибка прогноза (скользящее сглаживание)')
plt.show()
