# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
# %matplotlib inline
#%matplotlib qt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import Dropout

import tensorflow as tf

import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd

import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot
import cufflinks

from random import random
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
file_path='data4.csv'
df = pd.read_csv(file_path,sep=";",header=[0],skiprows=0,na_values=['Missing','nan','Offln'])
#df = df[0::30]
df.head()
# Out:
#              timestamp  1_GORKA +2/+4: u09 S5 Темп degc  \
# 0  2020-11-01 00:00:00                            -3.00
# 1  2020-11-01 00:02:00                            -3.00
# 2  2020-11-01 00:04:00                            -1.39
# 3  2020-11-01 00:06:00                            -0.11
# 4  2020-11-01 00:08:00                             0.89
#
#    1_GORKA +2/+4: u69 Sair Темп degc  1_GORKA +2/+4: --- EKC состояние   \
# 0                               1.39                                0.0
# 1                               0.89                               11.0
# 2                               0.89                               11.0
# 3                               1.50                               11.0
# 4                               2.28                               11.0
#
#    3_GORKA 0/+2: --- EKC состояние   3_GORKA 0/+2: u69 Sair Темп degc  \
# 0                               0.0                              0.28
# 1                              14.0                              0.28
# 2                              14.0                              0.28
# 3                              14.0                              0.61
# 4                              14.0                              1.00
#
#    3_GORKA 0/+2: u09 S5 Темп degc  4_GORKA +2/+4: --- EKC состояние   \
# 0                           -3.28                               11.0
# 1                           -3.28                               14.0
# 2                           -0.78                               14.0
# 3                            0.00                               14.0
# 4                            0.00                               14.0
#
#    4_GORKA +2/+4: u69 Sair Темп degc  4_GORKA +2/+4: u09 S5 Темп degc  ...  \
# 0                               2.72                             5.28  ...
# 1                               3.78                             5.72  ...
# 2                               3.39                             6.00  ...
# 3                               5.28                             6.61  ...
# 4                               6.22                             7.22  ...
#
#    7_GORKA +2/+4: --- EKC состояние   7_GORKA +2/+4: u69 Sair Темп degc  \
# 0                                0.0                               3.28
# 1                                0.0                               3.28
# 2                                0.0                               2.28
# 3                               11.0                               1.72
# 4                               11.0                               1.72
#
#    7_GORKA +2/+4: u09 S5 Темп degc  111_MT_AG: Sc3 air on cond. degc  \
# 0                            -0.39                              6.22
# 1                            -0.39                              6.22
# 2                            -1.61                              6.22
# 3                            -2.11                              6.22
# 4                            -0.72                              6.22
#
#    111_MT_AG: Cond running cap. %  111_MT_AG: Cond. reference Bar  \
# 0                             0.0                           11.24
# 1                            26.0                           11.24
# 2                            26.0                           11.24
# 3                             0.0                           11.24
# 4                             0.0                           11.24
#
#    111_MT_AG: Cond. ctrl. pressure Bar  111_MT_AG: Comp. 2 status   \
# 0                                11.05                         5.0
# 1                                10.71                         5.0
# 2                                10.71                         5.0
# 3                                 9.76                         5.0
# 4                                10.06                         5.0
#
#    111_MT_AG: Comp. 1 status   111_MT_AG: Control pressure Bar
# 0                        16.0                             4.20
# 1                        16.0                             4.14
# 2                        16.0                             4.28
# 3                        16.0                             3.76
# 4                        16.0                             2.74
#
# [5 rows x 26 columns]

# %%
print(df.dtypes)
# Out:
# timestamp                               object
# 1_GORKA +2/+4: u09 S5 Темп degc        float64
# 1_GORKA +2/+4: u69 Sair Темп degc      float64
# 1_GORKA +2/+4: --- EKC состояние       float64
# 3_GORKA 0/+2: --- EKC состояние        float64
# 3_GORKA 0/+2: u69 Sair Темп degc       float64
# 3_GORKA 0/+2: u09 S5 Темп degc         float64
# 4_GORKA +2/+4: --- EKC состояние       float64
# 4_GORKA +2/+4: u69 Sair Темп degc      float64
# 4_GORKA +2/+4: u09 S5 Темп degc        float64
# 5_GORKA +2/+4: --- EKC состояние       float64
# 5_GORKA +2/+4: u69 Sair Темп degc      float64
# 5_GORKA +2/+4: u09 S5 Темп degc        float64
# 6_GORKA +2/+4: --- EKC состояние       float64
# 6_GORKA +2/+4: u69 Sair Темп degc      float64
# 6_GORKA +2/+4: u09 S5 Темп degc        float64
# 7_GORKA +2/+4: --- EKC состояние       float64
# 7_GORKA +2/+4: u69 Sair Темп degc      float64
# 7_GORKA +2/+4: u09 S5 Темп degc        float64
# 111_MT_AG: Sc3 air on cond. degc       float64
# 111_MT_AG: Cond running cap. %         float64
# 111_MT_AG: Cond. reference Bar         float64
# 111_MT_AG: Cond. ctrl. pressure Bar    float64
# 111_MT_AG: Comp. 2 status              float64
# 111_MT_AG: Comp. 1 status              float64
# 111_MT_AG: Control pressure Bar        float64
# dtype: object

# %%
n_point=800
fn_tr=6000
st_test=fn_tr-n_point
fn_test=10000
len_f=10000

Ft = df['1_GORKA +2/+4: u09 S5 Темп degc']
scaler = MinMaxScaler(feature_range=(0, 1))
F=np.array(Ft[:len_f])
F = F.reshape(-1, 1)
F = scaler.fit_transform(F)
F_tr = F[:fn_tr]
F_test = F[st_test:]
plt.figure(figsize = (10, 5))
plt.plot(F, 'k')
plt.plot(np.r_[:fn_tr],F_tr, 'b')
plt.plot(np.r_[st_test:fn_test],F_test, 'r')
plt.show()

# %%
#Предобработка исходных данных в формат, понимаемый слоем GRU-сети, в виде «порций» (batches) для обучения/валидации
from keras.preprocessing.sequence import TimeseriesGenerator
data_gen_tr = TimeseriesGenerator(F_tr, F_tr, length=n_point, sampling_rate=1, batch_size=fn_tr)
batch_0_tr = data_gen_tr[0]
x_tr, y_tr = batch_0_tr # вход и обучающий выход для сети
print(x_tr.shape) #Точки обучения
xx_tr=np.reshape(x_tr, (x_tr.shape[0], 1, x_tr.shape[1]))
yy_tr=y_tr
print(xx_tr.shape) # меняем местами размерности
print(yy_tr.shape) #
# Out:
# (5200, 800, 1)
# (5200, 1, 800)
# (5200, 1)

# %%
#Для тестовой проверки прогноза исходные точки аналогично представим в виде «порций»
data_gen_test = TimeseriesGenerator(F_test, F_test, length=n_point, sampling_rate=1, batch_size=fn_tr)
batch_0_test = data_gen_test[0]
x_test, y_test = batch_0_test
xx_test=np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1]))
yy_test = y_test
print(xx_test.shape)
print(yy_test.shape)
# Out:
# (4000, 1, 800)
# (4000, 1)

# %%
#Модель из 3 слоев GRU
from tensorflow.keras.utils import plot_model
model = Sequential()
model.add(GRU(units=50, return_sequences=True, input_shape=(1, n_point)))
model.add(Dropout(0.3))
model.add(GRU(units=50, return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=50))
model.add(Dense(units = 20))
model.compile(optimizer = 'Adam', loss = 'mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 1, 50)             127800
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 50)             0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 1, 50)             15300
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 50)             0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 50)                15300
# _________________________________________________________________
# dense (Dense)                (None, 20)                1020
# =================================================================
# Total params: 159,420
# Trainable params: 159,420
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Производим обучение нашей модели
history = model.fit(xx_tr, yy_tr, validation_data=(xx_test, yy_test), epochs = 100, verbose=1) # 100 эпох
# Out:
# Epoch 1/100
# 163/163 [==============================] - 24s 33ms/step - loss: 0.0269 - val_loss: 0.0145
# Epoch 2/100
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0119 - val_loss: 0.0122
# Epoch 3/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0104 - val_loss: 0.0112
# Epoch 4/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0095 - val_loss: 0.0111
# Epoch 5/100
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0089 - val_loss: 0.0111
# Epoch 6/100
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0085 - val_loss: 0.0110
# Epoch 7/100
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0080 - val_loss: 0.0109
# Epoch 8/100
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0076 - val_loss: 0.0111
# Epoch 9/100
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0076 - val_loss: 0.0122
# Epoch 10/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0071 - val_loss: 0.0099
# Epoch 11/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0068 - val_loss: 0.0096
# Epoch 12/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0068 - val_loss: 0.0094
# Epoch 13/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0064 - val_loss: 0.0095
# Epoch 14/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0063 - val_loss: 0.0093
# Epoch 15/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0060 - val_loss: 0.0092
# Epoch 16/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0059 - val_loss: 0.0092
# Epoch 17/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0061 - val_loss: 0.0091
# Epoch 18/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0061 - val_loss: 0.0090
# Epoch 19/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0057 - val_loss: 0.0090
# Epoch 20/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0058 - val_loss: 0.0089
# Epoch 21/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0056 - val_loss: 0.0090
# Epoch 22/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0054 - val_loss: 0.0092
# Epoch 23/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0052 - val_loss: 0.0085
# Epoch 24/100
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0050 - val_loss: 0.0097
# Epoch 25/100
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0051 - val_loss: 0.0089
# Epoch 26/100
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0051 - val_loss: 0.0098
# Epoch 27/100
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0053 - val_loss: 0.0094
# Epoch 28/100
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0049 - val_loss: 0.0090
# Epoch 29/100
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0048 - val_loss: 0.0083
# Epoch 30/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0050 - val_loss: 0.0090
# Epoch 31/100
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0047 - val_loss: 0.0086
# Epoch 32/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0049 - val_loss: 0.0092
# Epoch 33/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0047 - val_loss: 0.0092
# Epoch 34/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0046 - val_loss: 0.0093
# Epoch 35/100
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0045 - val_loss: 0.0079
# Epoch 36/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0045 - val_loss: 0.0081
# Epoch 37/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0047 - val_loss: 0.0081
# Epoch 38/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0046 - val_loss: 0.0078
# Epoch 39/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0047 - val_loss: 0.0080
# Epoch 40/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0045 - val_loss: 0.0083
# Epoch 41/100
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0045 - val_loss: 0.0082
# Epoch 42/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0044 - val_loss: 0.0081
# Epoch 43/100
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0044 - val_loss: 0.0077
# Epoch 44/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0042 - val_loss: 0.0081
# Epoch 45/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0042 - val_loss: 0.0087
# Epoch 46/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0042 - val_loss: 0.0097
# Epoch 47/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0043 - val_loss: 0.0078
# Epoch 48/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0040 - val_loss: 0.0077
# Epoch 49/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0040 - val_loss: 0.0077
# Epoch 50/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0041 - val_loss: 0.0077
# Epoch 51/100
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0039 - val_loss: 0.0083
# Epoch 52/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0041 - val_loss: 0.0097
# Epoch 53/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0039 - val_loss: 0.0078
# Epoch 54/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0039 - val_loss: 0.0102
# Epoch 55/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0040 - val_loss: 0.0085
# Epoch 56/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0040 - val_loss: 0.0085
# Epoch 57/100
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0038 - val_loss: 0.0079
# Epoch 58/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0038 - val_loss: 0.0084
# Epoch 59/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0038 - val_loss: 0.0080
# Epoch 60/100
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0043 - val_loss: 0.0080
# Epoch 61/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0039 - val_loss: 0.0088
# Epoch 62/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0039 - val_loss: 0.0078
# Epoch 63/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0043 - val_loss: 0.0087
# Epoch 64/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0038 - val_loss: 0.0089
# Epoch 65/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0037 - val_loss: 0.0077
# Epoch 66/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0037 - val_loss: 0.0078
# Epoch 67/100
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0039 - val_loss: 0.0084
# Epoch 68/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0037 - val_loss: 0.0083
# Epoch 69/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0035 - val_loss: 0.0075
# Epoch 70/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0038 - val_loss: 0.0079
# Epoch 71/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0038 - val_loss: 0.0077
# Epoch 72/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0037 - val_loss: 0.0078
# Epoch 73/100
# 163/163 [==============================] - 2s 10ms/step - loss: 0.0037 - val_loss: 0.0076
# Epoch 74/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0034 - val_loss: 0.0078
# Epoch 75/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0037 - val_loss: 0.0075
# Epoch 76/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0038 - val_loss: 0.0076
# Epoch 77/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0041 - val_loss: 0.0077
# Epoch 78/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0037 - val_loss: 0.0081
# Epoch 79/100
# 163/163 [==============================] - 2s 9ms/step - loss: 0.0035 - val_loss: 0.0078
# Epoch 80/100
# 163/163 [==============================] - 1s 9ms/step - loss: 0.0037 - val_loss: 0.0082
# Epoch 81/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0038 - val_loss: 0.0077
# Epoch 82/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0034 - val_loss: 0.0082
# Epoch 83/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0035 - val_loss: 0.0074
# Epoch 84/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0034 - val_loss: 0.0083
# Epoch 85/100
# 163/163 [==============================] - 1s 8ms/step - loss: 0.0037 - val_loss: 0.0081
# Epoch 86/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0035 - val_loss: 0.0076
# Epoch 87/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0035 - val_loss: 0.0074
# Epoch 88/100
# 163/163 [==============================] - 1s 8ms/step - loss: 0.0034 - val_loss: 0.0082
# Epoch 89/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0035 - val_loss: 0.0078
# Epoch 90/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0034 - val_loss: 0.0077
# Epoch 91/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0034 - val_loss: 0.0076
# Epoch 92/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0032 - val_loss: 0.0076
# Epoch 93/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0035 - val_loss: 0.0091
# Epoch 94/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0037 - val_loss: 0.0078
# Epoch 95/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0034 - val_loss: 0.0076
# Epoch 96/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0033 - val_loss: 0.0077
# Epoch 97/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0034 - val_loss: 0.0077
# Epoch 98/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0033 - val_loss: 0.0074
# Epoch 99/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0033 - val_loss: 0.0080
# Epoch 100/100
# 163/163 [==============================] - 1s 7ms/step - loss: 0.0032 - val_loss: 0.0074

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  epochs = range(len(loss))
  plt.figure(figsize = (10, 5))
  plt.plot(epochs, loss, 'b', label='Потери при обучении')
  plt.plot(epochs, val_loss, 'r', label='Потери при проверке')
  plt.title(title)
  plt.legend()
  plt.show()

# %%
#%matplotlib qt
plot_train_history(history,
                   'График зависимости потерь при обучении и проверке модели от количества эпох')

# %%
#Построим ретроспективный прогноз
trainPredict = model.predict(xx_tr)
trainPredict = scaler.inverse_transform(trainPredict)
plt.figure(figsize = (10, 5))
plt.plot(Ft[:len_f], 'k')
plt.plot(np.r_[n_point:fn_tr],trainPredict, 'b')
plt.show()

# %%
#Ошибка
FF1=np.array(Ft[n_point:fn_tr]).reshape(-1,1)
er1=abs(FF1-trainPredict)
plt.figure(figsize = (10, 5))
plt.plot(er1, 'r')
plt.title('Ошибка обучения')
plt.show()

# %%
#Строим получившийся тестовый прогноз в нужном масштабе
#%matplotlib qt
testPredict = model.predict(xx_test)
testPredict = scaler.inverse_transform(testPredict)
plt.figure(figsize = (10, 5))
plt.plot(Ft[:len_f], 'k')
plt.plot(np.r_[fn_tr:len_f],testPredict, 'b')
plt.show()
#cufflinks.go_offline()
#cufflinks.set_config_file(world_readable=True, theme='pearl', offline=True)

# %%
#Ошибка
FF=np.array(Ft[fn_tr:len_f]).reshape(-1,1)
er=abs(FF-testPredict)
plt.figure(figsize = (10, 5))
plt.plot(np.r_[fn_tr:len_f],er, 'r')
plt.title('Ошибка прогноза')
plt.show()

# %%
print('Матожидание ошибки обучения = ', round(np.mean(er1),5))
print('СКВО ошибки обучения = ', round(np.std(er1),5))
print('Матожидание ошибки прогноза = ', round(np.mean(er),5))
print('СКВО ошибки прогноза = ', round(np.std(er),5))
# Out:
# Матожидание ошибки обучения =  0.45271
# СКВО ошибки обучения =  0.3683
# Матожидание ошибки прогноза =  0.8215
# СКВО ошибки прогноза =  0.69451

# %%
#Скользящее сглаживание по k точкам
def moving_average(series, Date, k):
    f2=[]
    Dt=[]
    N1=int(len(series))
    k1=int((k-1)/2)
    i=k1+1
    while i<= N1-k1:
        tmp=series[i-k1:i+k1]   
        f2.append(np.mean(tmp))
        Dt.append(Date[i])
        i=i+1
    return Dt, f2

# %%
#Скользящее сглаживание ошибки прогноза
[t1,s1] = moving_average(er, np.r_[fn_tr:len_f], 50)
plt.figure(figsize = (10, 5))
plt.plot(t1, s1, 'r')
plt.title('Ошибка прогноза (скользящее сглаживание)')
plt.show()
